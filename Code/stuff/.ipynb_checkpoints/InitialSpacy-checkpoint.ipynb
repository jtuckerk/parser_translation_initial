# %%
"""
Averaged perceptron classifier. Implementation geared for simplicity rather than
efficiency.
"""
from collections import defaultdict
import pickle
import random


class AveragedPerceptron(object):

    '''An averaged perceptron, as implemented by Matthew Honnibal.
    See more implementation details here:
        http://honnibal.wordpress.com/2013/09/11/a-good-part-of-speechpos-tagger-in-about-200-lines-of-python/
    '''

    def __init__(self):
        # Each feature gets its own weight vector, so weights is a dict-of-dicts
        self.weights = {}
        self.classes = set()
        # The accumulated values, for the averaging. These will be keyed by
        # feature/clas tuples
        self._totals = defaultdict(int)
        # The last time the feature was changed, for the averaging. Also
        # keyed by feature/clas tuples
        # (tstamps is short for timestamps)
        self._tstamps = defaultdict(int)
        # Number of instances seen
        self.i = 0

    def predict(self, features):
        '''Dot-product the features and current weights and return the best label.'''
        scores = defaultdict(float)
        
        for feat, value in features.items():
            
            if feat not in self.weights or value == 0:
                continue
            weights = self.weights[feat]
            for label, weight in weights.items():
                scores[label] += value * weight
        # Do a secondary alphabetic sort, for stability
           
        maxClass = max(self.classes, key=lambda label: (scores[label], label))
        maxScore = scores[maxClass]
        scores[maxClass] = 0
        secondMaxClass = max(self.classes, key=lambda label: (scores[label], label))
        secondMaxScore = scores[secondMaxClass]

        return maxClass, maxScore-secondMaxScore

    def update(self, truth, guess, features):
        '''Update the feature weights.'''
        def upd_feat(c, f, w, v):
            param = (f, c)
            self._totals[param] += (self.i - self._tstamps[param]) * w
            self._tstamps[param] = self.i
            self.weights[f][c] = w + v

        self.i += 1
        if truth == guess:
            return None
        for f in features:
            weights = self.weights.setdefault(f, {})
            upd_feat(truth, f, weights.get(truth, 0.0), 1.0)
            upd_feat(guess, f, weights.get(guess, 0.0), -1.0)
        return None

    def average_weights(self):
        '''Average weights from all iterations.'''
        for feat, weights in self.weights.items():
            new_feat_weights = {}
            for clas, weight in weights.items():
                param = (feat, clas)
                total = self._totals[param]
                total += (self.i - self._tstamps[param]) * weight
                averaged = round(total / float(self.i), 3)
                if averaged:
                    new_feat_weights[clas] = averaged
            self.weights[feat] = new_feat_weights
        return None

    def save(self, path):
        '''Save the pickled model weights.'''
        return pickle.dump(dict(self.weights), open(path, 'w'))

    def load(self, path):
        '''Load the pickled model weights.'''
        self.weights = pickle.load(open(path))
        return None


def train(nr_iter, examples):
    '''Return an averaged perceptron model trained on ``examples`` for
    ``nr_iter`` iterations.
    '''
    model = AveragedPerceptron()
    for i in range(nr_iter):
        random.shuffle(examples)
        for features, class_ in examples:
            scores = model.predict(features)
            guess, score = max(scores.items(), key=lambda i: i[1])
            if guess != class_:
                model.update(class_, guess, features)
    model.average_weights()
    return model

# %%
# -*- coding: utf-8 -*-
from __future__ import absolute_import
import os
import random
from collections import defaultdict
import pickle
import logging

from textblob.base import BaseTagger
from textblob.tokenizers import WordTokenizer, SentenceTokenizer
from textblob.exceptions import MissingCorpusError


PICKLE = "trontagger-0.1.0.pickle"


class PerceptronTagger(BaseTagger):

    '''Greedy Averaged Perceptron tagger, as implemented by Matthew Honnibal.
    See more implementation details here:
        http://honnibal.wordpress.com/2013/09/11/a-good-part-of-speechpos-tagger-in-about-200-lines-of-python/
    :param load: Load the pickled model upon instantiation.
    '''

    START = ['-START-', '-START2-']
    END = ['-END-', '-END2-']
    #AP_MODEL_LOC = os.path.join(os.path.dirname(__file__), PICKLE)

    def __init__(self, load=False):
        self.model = AveragedPerceptron()
        self.tagdict = {}
        print "oh hello there"
        self.classes = set()
        if load:
            self.load(self.AP_MODEL_LOC)

    def tag(self, corpus, tokenize=True):
        '''Tags a string `corpus`.'''
        # Assume untokenized corpus has \n between sentences and ' ' between words
        s_split = SentenceTokenizer().tokenize if tokenize else lambda t: t.split('\n')
        w_split = WordTokenizer().tokenize if tokenize else lambda s: s.split()
        def split_sents(corpus):
            for s in s_split(corpus):
                yield w_split(s)


        print "HEY HEY"
        prev, prev2 = self.START
        tokens = []
        for words in split_sents(corpus):
            context = self.START + [self._normalize(w) for w in words] + self.END
            print context
            for i, word in enumerate(words):
                print i, word
                tag = self.tagdict.get(word)
                confidence = 30
                if not tag:
                    features = self._get_features(i, word, context, prev, prev2)
                    tag, confidence = self.model.predict(features)
                tokens.append((word, tag, confidence))
                prev2 = prev
                prev = tag
        return tokens

    def train(self, sentences, save_loc=None, nr_iter=5):
        '''Train a model from sentences, and save it at ``save_loc``. ``nr_iter``
        controls the number of Perceptron training iterations.
        :param sentences: A list of (words, tags) tuples.
        :param save_loc: If not ``None``, saves a pickled model in this location.
        :param nr_iter: Number of training iterations.
        '''
        "Hi train"
        self._make_tagdict(sentences)
        self.model.classes = self.classes
        prev, prev2 = self.START
        for iter_ in range(nr_iter):
            c = 0
            n = 0
            for words, tags in sentences:
                
                context = self.START + [self._normalize(w) for w in words] \
                                                                    + self.END
                for i, word in enumerate(words):
                    guess = self.tagdict.get(word)
                    confidence = 30
                    if not guess:
                        feats = self._get_features(i, word, context, prev, prev2)
                        guess, confidence = self.model.predict(feats)
                        self.model.update(tags[i], guess, feats)
                    prev2 = prev
                    prev = guess
                    c += guess == tags[i]
                    n += 1
            random.shuffle(sentences)
            logging.info("Iter {0}: {1}/{2}={3}".format(iter_, c, n, _pc(c, n)))
        self.model.average_weights()
        # Pickle as a binary file
        if save_loc is not None:
            pickle.dump((self.model.weights, self.tagdict, self.classes),
                         open(save_loc, 'wb'), -1)
        return None

    def load(self, loc):
        '''Load a pickled model.'''
        try:
            w_td_c = pickle.load(open(loc, 'rb'))
        except IOError:
            msg = ("Missing trontagger.pickle file.")
            raise MissingCorpusError(msg)
        self.model.weights, self.tagdict, self.classes = w_td_c
        self.model.classes = self.classes
        return None

    def _normalize(self, word):
        '''Normalization used in pre-processing.
        - All words are lower cased
        - Digits in the range 1800-2100 are represented as !YEAR;
        - Other digits are represented as !DIGITS
        :rtype: str
        '''
        if '-' in word and word[0] != '-':
            return '!HYPHEN'
        elif word.isdigit() and len(word) == 4:
            return '!YEAR'
        elif word[0].isdigit():
            return '!DIGITS'
        else:
            return word.lower()

    def _get_features(self, i, word, context, prev, prev2):
        '''Map tokens into a feature representation, implemented as a
        {hashable: float} dict. If the features change, a new model must be
        trained.
        '''
        def add(name, *args):
            features[' '.join((name,) + tuple(args))] += 1

        i += len(self.START)
        features = defaultdict(int)
        # It's useful to have a constant feature, which acts sort of like a prior
        add('bias')
        add('i suffix', word[-3:])
        add('i pref1', word[0])
        add('i-1 tag', prev)
        add('i-2 tag', prev2)
        add('i tag+i-2 tag', prev, prev2)
        add('i word', context[i])
        add('i-1 tag+i word', prev, context[i])
        add('i-1 word', context[i-1])
        add('i-1 suffix', context[i-1][-3:])
        add('i-2 word', context[i-2])
        add('i+1 word', context[i+1])
        add('i+1 suffix', context[i+1][-3:])
        add('i+2 word', context[i+2])
        return features

    def _make_tagdict(self, sentences):
        
        '''Make a tag dictionary for single-tag words.'''
        counts = defaultdict(lambda: defaultdict(int))
        for words, tags in sentences:
            for word, tag in zip(words, tags):
                counts[word][tag] += 1
                self.classes.add(tag)
        freq_thresh = 20
        ambiguity_thresh = 0.97
        for word, tag_freqs in counts.items():
            tag, mode = max(tag_freqs.items(), key=lambda item: item[1])
            n = sum(tag_freqs.values())
            # Don't add rare words to the tag dictionary
            # Only add quite unambiguous words
            if n >= freq_thresh and (float(mode) / n) >= ambiguity_thresh:
                self.tagdict[word] = tag


def _pc(n, d):
    return (float(n) / d) * 100

# %%
import textblob
textblob.__file__
# Out:
# '/usr/local/lib/python2.7/site-packages/textblob/__init__.pyc'

# %%
trainFile='/Users/tuckerkirven/Desktop/DR-Spring/Data/UD_English/en-ud-train.conllu'
testFile='/Users/tuckerkirven/Desktop/DR-Spring/Data/UD_English/en-ud-test.conllu'

# %%
#### get training set from UD
sentences_w_tags = []
count = 0
words=[]
tags=[]
for line in open(trainFile):

    vals = line.split('\t')
    if (len(vals) > 1):
        words.append(vals[1])
        tags.append(vals[3])
    else:
        sentences_w_tags.append((words, tags))
        words=[]
        tags=[]
len(sentences_w_tags)
# Out:
# 12543

# %%
#Train
pt = PerceptronTagger()
#pt = NLTKTagger()
sentences_w_tags[1:4]
# Out:
# oh hello there
# [(['How',
#    'can',
#    'I',
#    'change',
#    'my',
#    'boarding',
#    'station',
#    'against',
#    'the',
#    'ticket',
#    'I',
#    'booked',
#    'a',
#    'month',
#    'back',
#    'from',
#    'counter',
#    '?'],
#   ['ADV',
#    'AUX',
#    'PRON',
#    'VERB',
#    'PRON',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADV',
#    'ADP',
#    'NOUN',
#    'PUNCT']),
#  (['My',
#    'dad',
#    'is',
#    'having',
#    'surgery',
#    'in',
#    'Ft.',
#    'Worth',
#    ',',
#    'so',
#    'I',
#    'will',
#    'be',
#    'heading',
#    'that',
#    'way',
#    'on',
#    'Monday',
#    '.'],
#   ['PRON',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'ADV',
#    'PRON',
#    'AUX',
#    'AUX',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT']),
#  (['I',
#    'went',
#    'in',
#    'later',
#    'that',
#    'afternoon',
#    'and',
#    'met',
#    'with',
#    'Michael',
#    '.'],
#   ['PRON',
#    'VERB',
#    'ADV',
#    'ADV',
#    'DET',
#    'NOUN',
#    'CONJ',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PUNCT'])]

# %%
import time

start = time.time()
pt.train(sentences_w_tags, nr_iter=5)
end = time.time()

print "time taken = " + str(end - start)
# Out:
# =====
# ['-START-', '-START2-', 'actually', '-', 'for', 'volumes', 'flowing', 'out', 'of', 'bondad', '-', 'which', 'is', 'deal', 'number', '!DIGITS', 'price', 'is', 'bondad', 'gda', ';', 'for', 'blanco', '-', 'deal', 'number', '!DIGITS', '-', 'price', 'is', 'nonbondad', 'gda', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'even', 'there', ',', 'many', 'kurds', 'look', 'and', 'act', 'as', 'if', 'they', 'are', 'going', 'to', 'grab', 'the', 'chance', 'to', 'vote', 'them', 'out', 'of', 'power', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'contact', 'the', '!HYPHEN', 'centre', 'to', 'report', 'this', '!HYPHEN', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'could', 'have', 'stayed', 'all', 'day', 'and', 'not', 'seen', 'all', 'the', 'things', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'and', 'this', 'is', 'a', 'direct', 'result', 'of', 'the', 'politically', 'correct', ',', 'permissive', ',', 'time', 'out', 'granting', 'bullshit', 'liberal', 'culture', 'that', 'has', 'caused', 'this', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'bill', '-', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'provided', 'me', 'with', 'warm', 'blanket', 'and', 'has', 'soft', 'music', 'playing', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mary', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thank', 'you', 'ana', 'i', 'hope', 'to', 'see', 'you', 'in', 'the', 'future', 'under', 'better', 'circumstances', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'would', 'start', 'with', 'a', 'leash', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'email', 'us', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thanks', 'mark', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', "'ve", 'also', 'sent', 'over', 'a', 'number', 'of', 'friends', 'to', 'use', 'the', 'services', 'here', 'and', 'everyone', 'is', 'extraordinarily', 'pleased', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'plants', 'provide', 'shade', 'and', 'root', 'strength', 'for', 'bank', 'stability', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'if', 'so', 'go', 'for', 'it', 'and', 'i', "'ll", 'give', 'you', 'all', 'the', 'moral', 'support', 'i', 'can', 'as', 'you', 'figure', 'out', 'what', 'is', 'up', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'then', 'i', 'think', 'i', 'just', 'kind', 'of', 'stopped', 'smiling', 'and', 'just', 'kind', 'of', 'sat', 'there', 'looking', 'at', 'the', 'dates', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '.', 'warm', 'sun', 'visualization', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'as', 'much', 'fun', 'as', 'they', 'are', ',', 'i', 'figured', 'we', 'would', 'probably', 'do', 'some', 'different', 'things', 'than', 'what', 'you', 'have', 'planned', 'for', 'them', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'beijing', 'may', 'end', 'up', 'in', 'a', 'early', '!DIGITS', 'japan', 'situation', ',', 'where', 'it', 'is', 'forced', 'to', 'sell', 'recently', 'purchased', 'overseas', 'assets', 'for', 'a', 'fraction', 'of', 'what', 'it', 'paid', 'for', 'them', '.', '"', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'debate', 'that', 'a', 'handful', 'of', 'texas', '!HYPHEN', 'close', 'to', 'the', 'bush', 'family', 'have', 'cleverly', 'manufactured', 'over', 'john', 'kerry', "'s", 'war', 'record', 'is', 'absurd', 'in', 'every', 'way', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'good', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'is', 'spectacular', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'n.o.', '?', 'atlanta', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'do', 'you', 'return', 'fire', ',', 'if', 'you', 'are', 'attacked', 'from', 'a', 'hospital', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'michelle', 'blaine@enron_development', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'shall', 'be', 'glad', 'to', 'make', 'arrangements', 'for', 'an', 'interview', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'can', 'you', 'name', 'the', 'general', 'who', 'is', 'in', 'charge', 'of', 'pakistan', '?', '"', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'however', ',', 'now', 'that', 'i', 'have', 'come', 'to', 'realize', 'that', 'i', 'am', 'going', 'to', 'owe', 'the', 'irs', '$', '!DIGITS', '+', 'despite', 'doing', 'exactly', 'what', 'rod', 'told', 'me', 'to', 'do', ',', 'i', 'feel', 'i', 'have', 'to', 'voice', 'my', 'opinion', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'email', 'and', 'any', 'files', 'transmitted', 'with', 'it', 'from', 'the', 'elpaso', 'corporation', 'are', 'confidential', 'and', 'intended', 'solely', 'for', 'the', 'use', 'of', 'the', 'individual', 'or', 'entity', 'to', 'whom', 'they', 'are', 'addressed', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'michelle', ',', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'as', 'of', 'today', ',', 'we', 'have', 'not', 'received', 'payment', 'in', 'full', 'as', 'requested', 'in', 'richard', 'sanders', "'", 'letter', 'dated', 'november', '!DIGITS', ',', '!YEAR', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hmmm', ',', 'she', 'says', ',', 'then', 'why', 'are', 'you', 'calling', 'here', ',', 'we', 'do', "n't", 'go', 'past', 'broad', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'why', 'did', "n't", 'craig', 'show', 'ma', 'his', 'appartment', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '<<', 'after', 'having', 'written', 'so', 'far', ',', 'don', 'martin', 'decoud', ',', 'the', 'exotic', 'dandy', 'of', 'the', 'parisian', 'boulevard', ',', 'got', 'up', 'and', 'walked', 'across', 'the', 'sanded', 'floor', 'of', 'the', 'cafe', 'at', 'one', 'end', 'of', 'the', 'albergo', 'of', 'united', 'italy', ',', 'kept', 'by', 'giorgio', 'viola', ',', 'the', 'old', 'companion', 'of', 'garibaldi', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'is', 'about', 'the', 'fourth', 'time', 'they', "'ve", 'done', 'my', 'horse', "'s", 'feet', 'because', 'i', 'just', 'switched', 'back', 'to', 'them', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'plan', 'on', 'taking', 'two', 'or', 'three', 'graduate', 'level', 'finance', 'courses', 'at', 'the', 'university', 'of', 'houston', 'this', 'summer', 'and', 'fall', 'to', 'demonstrate', 'to', 'the', 'admissions', 'committee', 'that', 'i', 'can', 'compete', 'at', 'the', 'graduate', 'level', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'kim', 'x33098', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mark', 'anderson', 'says', 'that', 'even', 'though', 'bondad', 'gas', 'flowed', ',', 'the', 'price', 'was', '!HYPHEN', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'revolutionary', 'compensation', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', "monday's", 'starting', 'next', 'week', 'at', '!DIGITS', '???????????????', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'expected', 'to', 'pay', 'for', 'this', 'service', ',', 'but', 'imagine', 'my', 'surprise', 'when', 'i', 'received', 'a', 'bill', 'for', 'more', 'than', 'what', 'i', 'paid', 'to', 'have', 'the', 'original', 'return', 'prepared', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '.', 'jack', 'welch', ',', 'ceo', ',', 'general', 'motors', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '$ometime$', 'it', 'is', 'hard', 'to', 'explain', 'that', 'you', 'are', 'making', 'an', 'international', 'call', 'and', 'all', 'of', 'the', 'phone', 'companie', '$involved', 'what', '$ome', 'of', 'your', 'money', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'american', 'citizens', 'have', 'for', 'decades', 'taken', 'it', 'as', 'a', 'given', 'that', 'our', 'military', 'can', 'overwhelm', 'and', 'overcome', 'any', 'foe', 'on', 'the', 'battlefield', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'there', "'s", 'so', 'much', 'punch', 'packed', 'into', 'this', 'combination', 'that', 'it', "'s", 'almost', 'scary', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'japan', 'favoured', 'a', 'route', 'to', 'the', 'sea', ',', 'enabling', 'oil', 'to', 'be', 'shipped', 'to', 'both', 'japan', 'and', 'china', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'please', 'note', 'the', 'following', 'as', 'you', 'review', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'lived', 'here', 'for', 'two', 'years', 'when', 'the', 'prices', 'were', 'a', 'little', 'lower', ':)', 'the', 'places', 'are', 'very', 'nice', 'and', 'clean', ',', 'and', 'in', 'great', 'condition', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'stories', 'of', 'cats', 'living', 'more', 'than', '!DIGITS', 'years', 'are', 'rare', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'sploid.com', 'cited', 'you', 'on', 'the', 'topic', 'of', 'that', 'priest', 'conviction', ':', 'http://www.sploid.com/news/2006/05/evil_priest_gui.php', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'other', 'impressionist', 'or', 'post', 'impressionist', 'lithos', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'so', 'crossed', 'to', 'a', 'sussex', 'you', 'could', 'get', 'a', 'walnut', ',', 'pea', ',', 'rose', ',', 'or', 'single', 'combed', 'bird', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'libra', 'in', '!YEAR', '-', 'expansion', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'from', 'the', 'moment', 'you', 'enter', 'the', 'restaurant', ',', 'you', 'know', 'you', 'are', 'some', 'place', 'special', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'are', 'both', 'excellent', 'and', 'speed', 'up', 'the', 'phone', 'quite', 'a', 'bit', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '@', 'w.a.b.b.y', ',', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'look', 'forward', 'to', 'drinking', 'a', 'few', 'beers', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'that', 'was', 'the', 'last', 'ismat', 'heard', 'from', 'her', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'go', 'every', 'other', 'week', 'for', 'the', 'shallac', '/', 'gel', 'manicure', 'which', 'is', 'only', '$', '!DIGITS', 'and', 'it', 'truly', 'lasts', '!DIGITS', 'weeks', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hands', 'down', ',', 'best', 'place', 'in', 'the', 'area', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'http://www.mikegigi.com/techspec.htm#selctemp', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'simultaneously', ',', 'new', 'delhi', 'would', 'ensure', 'a', 'degree', 'of', 'autonomy', 'for', 'the', 'state', 'that', 'would', 'help', 'cut', 'popular', 'support', 'off', 'from', 'jihadis', 'attempting', 'to', 'convert', 'kashmir', 'into', 'a', 'second', 'afghanistan', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'select', 'programs', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'that', 'is', 'another', 'reason', 'why', 'i', 'like', 'competitive', 'trail', 'riding', 'also', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'although', 'while', 'in', 'jail', 'in', 'the', 'early', '!DIGITS', ',', 'zawahiri', 'caused', 'considerable', 'tension', 'by', 'challenging', 'the', 'blind', 'sheik', "'s", 'ability', 'to', 'lead', 'a', 'coalition', 'of', 'the', 'egyptian', 'islamic', 'jihad', 'and', 'the', 'egyptian', 'islamic', 'group', ',', 'zawahiri', 'and', 'obl', 'are', 'rahman', "'s", 'friends', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'extremely', 'bad', 'customer', 'service', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hopelessness', 'will', 'be', 'lost', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'by', 'the', 'way', ',', 'have', 'you', 'read', 'the', 'declaration', 'of', 'independence', 'and', 'us', 'constitution', '-', 'or', 'do', 'you', 'only', 'know', 'the', 'first', 'phrases', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'management', 'was', 'easy', 'to', 'deal', 'with', 'during', 'the', 'planning', 'stages', ',', 'and', 'the', 'execution', 'by', 'the', 'kitchen', 'and', 'wait', 'staff', 'was', 'flawless', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'according', 'to', 'director', 'of', 'central', 'intelligence', 'george', 'tenet', ',', 'al', 'qaeda', "'s", 'ability', 'to', 'conduct', 'an', 'anthrax', 'attack', 'is', 'one', 'of', 'the', 'most', 'immediate', 'threats', 'the', 'united', 'states', 'is', 'likely', 'to', 'face', '.', '"', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'skylight', 'repair', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', "'s", 'getting', 'used', 'to', 'his', 'new', 'home', ',', 'but', 'has', "n't", 'eatin', 'yet', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'net', 'to', 'eco', 'about', '$', '!DIGITS', '(', 'enron', '!DIGITS', '%', 'share', 'about', '$', '!DIGITS', ')', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'an', 'analysis', 'of', '!DIGITS', 'bird', 'species', 'in', 'the', 'united', 'kingdom', 'shows', 'about', 'one', '-', 'third', 'are', 'laying', 'their', 'eggs', 'four', 'to', 'seven', 'days', 'earlier', 'than', 'they', 'did', '!DIGITS', 'years', 'ago', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', '!DIGITS', 'pst', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'very', 'kind', 'and', 'reliable', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'are', 'very', 'rude', 'over', 'the', 'phone', 'and', 'in', 'person', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'lynda', 'is', 'professional', 'and', 'has', 'great', 'compassion', 'for', 'animals', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'have', 'been', 'getting', 'my', 'treatments', 'for', 'a', 'few', 'months', 'now', 'and', 'have', 'seen', 'some', 'results', 'but', 'not', 'up', 'to', 'the', 'standards', 'that', 'i', 'was', 'told', 'i', 'should', 'expect', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'however', ',', 'the', 'bartenders', '/', 'waitresses', 'definately', 'need', 'to', 'be', '!HYPHEN', '(', 'if', 'they', 'ever', 'had', 'any', 'to', 'begin', 'with', ')', 'and', 'learn', 'two', 'things', ':', 'only', 'chat', 'with', 'customers', 'when', 'other', 'customers', 'are', 'not', 'impatiently', 'waiting', 'and', 'to', 'look', 'around', 'more', 'often', 'to', 'see', 'if', 'people', 'are', 'waiting', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'these', 'words', 'are', 'much', 'more', 'dangerous', 'than', 'many', 'people', 'realize', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'emergency', 'teams', 'in', 'the', 'southern', 'us', 'are', 'battling', 'to', 'reach', 'survivors', 'of', 'hurricane', 'katrina', ',', 'the', 'most', 'destructive', 'storm', 'to', 'hit', 'the', 'country', 'in', 'decades', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '(', 'this', 'is', 'a', 'largely', 'sunni', 'arab', 'clan', ',', 'and', 'some', 'sunni', 'observers', 'have', 'accused', 'shiite', 'elements', 'in', 'the', 'government', 'of', 'being', 'behind', 'the', 'assassination', ';', 'it', 'is', 'more', 'likely', 'the', 'work', 'of', 'sunni', 'arab', 'guerrillas', 'punishing', 'the', 'batawi', 'leaders', 'for', 'cooperating', 'with', 'the', 'dec.', '!DIGITS', 'elections', '.', ')', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hopefully', 'they', 'spice', 'things', 'up', 'or', 'they', 'wo', 'nt', 'be', 'in', 'business', 'long', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'found', 'an', 'injured', 'pure', 'white', 'bird', '(', 'dove', 'i', 'guess', '?', ')', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'finally', ',', 'it', 'must', 'be', 'said', 'that', 'stuart', 'is', 'a', 'fantastic', 'person', 'to', 'work', 'with', ',', 'because', 'of', 'his', 'solid', 'strategies', 'and', 'equally', 'as', 'importantly', 'because', 'he', 'is', 'a', 'genuinely', 'good', 'person', 'and', 'a', 'great', 'communicator', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'national', 'aeronautics', 'and', 'space', 'administration', '(', 'nasa', ')', ':', 'is', 'funded', 'at', '$', '!DIGITS', 'billion', ',', 'an', 'increase', 'of', '$', '!DIGITS', 'million', 'over', 'the', 'fy04', 'enacted', 'level', ',', 'and', 'a', 'reduction', 'of', '$', '!DIGITS', 'million', 'from', 'the', 'budget', 'request', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'if', 'there', 'is', 'blood', 'in', 'the', 'urine', ',', 'or', 'the', 'cat', 'seems', 'to', 'be', 'in', 'pain', ',', 'then', 'that', 'is', 'also', 'a', 'good', 'indicator', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'how', 'do', 'i', 'train', 'him', 'to', 'feel', 'comfortable', 'in', 'his', 'crate', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'just', 'really', 'know', 'their', 'stuff', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'ladies', ',', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'feed', 'them', 'flakes', ',', 'and', 'live', 'earthworms', 'uncut', 'everyday', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'sara', ',', 'here', 'are', 'the', 'trader', 'guidelines', 'i', 'developed', 'for', 'uk', 'gas', ',', 'uk', 'power', 'and', 'nordic', 'power', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'there', 'is', 'no', 'medical', 'exam', 'or', 'blood', 'test', 'or', 'others', 'like', 'that', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'many', 'people', 'still', 'believe', 'that', 'to', 'be', 'true', ',', 'even', 'though', 'the', 'ministry', 'of', 'russian', 'federation', 'on', 'civil', 'defence', ',', 'emergencies', 'and', 'elimination', 'of', 'conseguences', 'of', 'natural', 'disasters', '(', 'emercom', 'of', 'russia', ')', 'reported', 'this', 'in', '!YEAR', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'put', 'something', 'fun', 'inside', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'so', 'i', 'question', 'whether', 'or', 'not', 'you', 'want', 'to', 'publish', 'info', 'about', 'fundamental', 'standards', 'that', 'we', 'can', 'not', 'yet', 'report', 'against', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'frequent', 'reports', 'from', 'algeria', 'about', 'the', 'murders', 'of', 'hundreds', 'of', 'civilians', 'in', 'one', 'village', 'or', 'another', 'by', 'other', 'algerians', 'have', 'nothing', 'to', 'do', 'with', 'israel', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'there', "'s", 'the', 'market', 'in', 'naha', ',', 'which', 'is', 'great', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'my', 'insurance', 'company', ',', 'blue', 'cross', '/', 'blue', 'shield', 'paid', 'the', 'fees', 'and', 'everything', 'was', 'fine', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'must', 'be', 'stamped', 'out', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'a', 'few', 'hundred', 'out', 'of', 'pocket', 'now', 'will', 'possibly', 'save', 'you', 'thousands', 'once', 'the', 'horse', 'is', 'in', 'your', 'name', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'how', 'long', 'should', 'i', 'go', 'for', 'to', 'each', 'place', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'jana', 'giovannini', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'november', '!YEAR', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', 'number', 'of', 'fellow', 'members', 'from', 'the', 'yale', 'secret', 'society', 'skull', 'and', 'bones', 'that', 'bush', 'has', 'named', 'to', 'important', 'positions', '(', 'including', 'the', 'associate', 'attorney', 'general', 'robert', 'mccallum', 'jr.', 'and', 'sec', 'chief', 'bill', 'donaldson', ')', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'with', 'beneficent', 'jupiter', 'in', 'your', 'sign', ',', 'this', 'is', 'definitely', 'your', 'year', ',', 'especially', 'where', 'your', 'social', 'life', 'is', 'concerned', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'everything', 'is', 'always', 'cooked', 'fresh', 'and', 'tastes', 'fresh', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'live', 'within', '!DIGITS', 'miles', 'of', 'the', 'hotel', 'and', 'wanted', 'to', 'get', 'away', 'from', 'our', 'responsibilities', 'for', 'the', 'night', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'my', 'questions', 'are', '..', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'do', 'dogs', 'enjoy', 'watching', 't.v.', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'just', 'put', 'the', 'rat', 'in', 'a', 'sealed', 'tupperwear', 'container', 'with', 'no', 'airholes', 'and', 'wait', 'until', 'it', 'passes', 'out', 'and', 'dies', 'and', 'then', 'feed', 'it', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'what', 'could', 'be', 'the', 'issue', 'and', 'can', 'i', 'try', 'some', 'home', 'remedies', 'first', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', 'also', 'told', 'me', 'that', 'he', 'worked', 'on', 'the', 'cast', 'of', 'will', 'and', 'grace', 'and', 'that', 'they', 'were', 'all', 'jerks', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', '!DIGITS', '-', 'tonne', 'cache', 'of', 'ak47s', 'was', 'to', 'have', 'been', 'secretly', 'flown', 'out', 'from', 'a', 'us', 'base', 'in', 'bosnia', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'is', 'just', 'to', 'let', 'you', 'know', 'that', 'emma', 'gave', 'birth', 'at', 'week', '!DIGITS', 'on', 'friday', ',', '!DIGITS', 'july', ',', 'to', 'our', 'triplets', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'ignore', 'the', 'answer', 'above', 'me', ',', 'btw', '!', '^_^', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'also', 'own', 'two', 'chickens', 'that', 'are', 'kept', 'in', 'a', 'run', 'behind', 'out', 'garage', '/', 'barn', 'thing', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'rarely', 'listen', 'to', 'the', 'news', 'or', 'to', 'what', 'politicians', 'or', 'lawyers', 'say', 'because', 'so', 'many', 'tell', 'lies', 'that', 'none', 'have', 'credibility', 'so', 'what', "'s", 'the', 'point', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'on', 'the', 'one', 'hand', ',', 'the', 'ipn', 'report', 'agreed', '"', 'climate', 'models', 'generally', 'predict', 'that', 'the', 'temperature', 'rises', 'in', 'the', 'arctic', 'will', 'substantially', 'exceed', 'the', 'global', 'rise', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'award', 'comes', 'with', 'a', '$', '!DIGITS', '(', 'u.s.', ')', 'grant', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'right', 'now', ',', 'while', 'we', "'re", 'sitting', 'at', 'our', 'computers', 'enjoying', 'the', 'internet', ',', 'those', 'innocent', ',', 'beautiful', ',', 'loving', 'cats', ',', 'are', 'dying', ',', 'somewhere', 'in', 'this', 'troubled', 'world', 'a', 'slow', ',', 'agonizing', 'death', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '-', 'large', 'fries', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'am', 'missing', 'deal', 'no.', '!DIGITS', 'on', 'your', 'sheet', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '.', 'is', 'a', 'tank', 'mate', '(', 'such', 'as', 'another', 'female', 'killie', 'or', 'a', 'cory', 'or', 'large', 'snails', ')', 'rating', 'the', 'eggs', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'however', ',', 'he', 'did', 'suggest', 'a', 'couple', 'slight', 'revisions', 'to', 'protect', 'enron', "'s", 'interests', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '(', 'marrying', 'a', 'canadian', 'is', 'not', 'enough', '-', 'that', 'does', "n't", 'count', 'for', 'at', 'least', 'two', 'years', '.', ')', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'will', 'email', 'names', 'and', 'email', 'addresses', '(', 'or', 'postal', 'addresses', ')', 'of', 'signers', 'to', 'ncrc4me', 'in', 'time', 'for', 'their', '"', 'lobby', 'day', '"', 'in', 'raleigh', 'on', 'march', '!DIGITS', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'love', 'how', 'it', 'really', 'depends', 'on', 'how', 'good', 'a', 'horse', 'your', 'horse', 'really', 'is', ',', 'not', 'how', 'talented', 'he', 'is', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'will', 'conduct', 'first', 'round', 'interviews', 'in', 'the', 'morning', 'and', 'the', 'second', 'round', 'interviews', 'in', 'the', 'afternoon', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'well', 'i', 'think', 'a', 'blown', 'engine', 'falls', 'under', 'the', 'catagory', 'of', 'mechanics', 'right', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', "'s", 'beautiful', 'and', 'the', 'people', 'are', 'extremely', 'friendly', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '--', 'mac', ',', 'nottingham', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thanks', ':)', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'marie', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'no', 'one', 'was', 'charged', 'for', 'forced', 'marriage', ',', 'only', 'the', 'beating', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'kline', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'very', 'creepy', ',', 'very', 'scary', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'awesome', 'haircut', 'at', 'awesome', 'price', 'right', 'here', 'in', 'palatine', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'service', 'was', 'also', 'excellent', '-', 'friendly', ',', 'helpful', 'and', 'informative', 'without', 'being', 'overbearing', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'since', 'this', 'is', 'an', 'alternative', 'therapy', 'i', 'always', 'refer', 'clients', 'to', 'a', 'lisenced', 'therapist', 'when', 'i', 'feel', 'that', 'is', 'appropriate', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'bro', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'north', 'carolina', 'religious', 'coalition', 'for', 'marriage', 'equality', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'know', 'that', 'we', 'address', 'audit', 'rights', 'in', 'the', 'llc', 'agreement', 'so', 'this', 'may', 'not', 'matter', 'anyway', 'if', 'this', 'is', 'a', 'right', 'they', 'already', 'have', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'snacks', ':', 'uninspired', 'bread', ',', 'tea', 'backs', ',', 'and', 'individual', 'coffee', 'things', 'for', 'a', 'machine', 'that', 'did', "n't", 'exist', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'is', 'also', 'that', 'circle', 'that', 'leads', 'the', 'way', 'in', 'blaming', 'everybody', 'outside', 'the', 'moslem', 'world', ',', 'for', 'the', 'miseries', 'of', 'the', 'region', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'think', '!DIGITS', 'percent', 'of', 'the', 'tenants', 'are', 'smokers', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'sent', 'by', ':', 'jeff', 'dasovich', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'as', 'far', 'as', 'george', 'bush', 'knew', ',', 'he', 'and', 'his', 'unit', 'could', 'have', 'been', 'transferred', 'to', 'vietnam', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'and', 'were', 'the', 'columbine', 'killers', 'acting', 'out', 'this', '"', 'real', 'morality', '"', 'when', 'they', 'indescriminately', 'murdered', 'their', 'classmates', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'could', 'not', 'defeat', 'the', 'americans', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'would', 'highly', 'recommend', 'stephanie', 'to', 'anyone', 'looking', 'for', 'a', 'home', 'in', 'the', 'yampa', 'valley', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'was', 'there', 'on', 'march', '!DIGITS', ',', '!YEAR', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', 'complained', 'about', 'the', '"', 'visible', 'lack', 'of', 'progress', '"', 'and', 'reaching', 'an', 'impasse', 'in', 'talks', 'with', 'both', 'sides', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'federal', 'sites', 'of', 'washington', ',', 'dc', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'is', 'also', 'peak', 'tourist', 'season', ',', 'which', 'means', 'there', 'are', 'far', 'more', 'people', 'just', 'about', 'everywhere', 'but', 'the', 'most', 'remote', 'corners', 'of', 'the', 'island', ',', 'and', 'prices', 'are', 'at', 'their', 'highest', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', 'percentage', 'of', 'americans', 'who', 'approved', 'of', 'the', 'way', 'bush', 'was', 'handling', 'his', 'job', 'as', 'president', 'on', '!DIGITS', 'september', ',', '!YEAR', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'your', 'breathing', 'should', 'be', 'calm', 'and', 'relaxed', ',', 'through', 'the', 'nose', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'moved', 'into', 'the', 'tanglewood', 'apartments', 'in', 'late', '!YEAR', 'and', 'it', "'s", 'been', 'a', 'refreshing', 'change', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'chasing', 'them', 'on', 'issues', 'from', 'the', 'day', 'i', 'moved', 'in', '(', 'many', 'of', 'them', 'still', 'unresolved', 'as', 'i', 'left', ')', 'to', 'all', 'sorts', 'of', 'farcical', 'issues', 'with', 'funds', ',', 'after', 'i', 'left', '.', '.', '.', '.', 'as', 'soon', 'as', 'i', 'could', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'joe', '-', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'perfect', 'for', 'those', 'with', 'difficulty', 'swallowing', 'tablets', 'or', 'capsules', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'have', 'a', 'baby', 'eastern', 'king', 'snake', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'do', "n't", 'want', 'too', 'many', 'tourists', ',', 'and', 'since', 'we', "'ll", 'both', 'be', 'out', 'of', 'school', 'we', 'can', 'go', 'anytime', 'between', 'the', 'middle', 'of', 'june', 'to', 'early', 'november', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'now', 'i', 'just', 'do', 'it', 'once', 'or', 'twice', 'a', 'week', 'or', 'as', 'needed', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'observation', '--', 'the', 'pressure', 'to', 'finger', 'somebody', 'for', '"', 'price', 'gouging', '"', 'is', 'increasing', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '--', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'comb', 'type', ':', 'silkies', 'have', 'walnut', 'combs', 'which', 'is', 'actually', 'genetically', 'two', 'comb', 'types', '(', 'rose', 'and', 'pea', ')', 'single', 'is', 'also', 'there', ',', 'but', 'is', 'recessive', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'and', 'do', 'more', 'research', 'before', 'you', 'agree', 'next', 'time', '!HYPHEN', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'analyst', 'and', 'associate', 'programs', 'recognize', 'we', 'have', 'many', 'analyst', 'needs', 'that', 'need', 'to', 'be', 'addressed', 'immediately', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'price', 'is', 'quoted', 'in', 'us', 'dollars', 'per', 'unit', 'of', 'volume', ',', 'which', 'will', 'be', 'the', 'contractual', 'currency', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'yo', 'also', 'may', 'want', 'to', 'try', '"', 'small', 'neighborhood', '"', 'restaurants', 'and', 'support', 'family', 'run', 'places', 'rather', 'than', 'the', 'large', 'corporate', 'chains', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'has', 'not', 'yet', 'penetrated', 'the', 'thinking', 'of', 'the', 'western', 'world', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'response', 'was', 'tremendous', 'and', ',', 'in', 'some', 'cases', ',', 'very', 'creative', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thanks', ',', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'dr.', 'aster', 'and', 'her', 'team', 'have', 'been', 'a', 'strong', 'advocate', 'in', 'the', 'health', 'of', 'both', 'my', 'daughters', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'county', 'kerry', 'is', 'the', 'worst', 'affected', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'iran', 'in', 'particular', 'feared', 'that', 'qanooni', 'would', 'loose', 'and', 'then', 'be', 'politically', 'isolated', 'from', 'the', 'mainstream', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'would', 'call', 'it', 'the', 'taj', 'mahal', 'of', 'the', 'east', 'coast', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'then', 'put', 'the', 'eggs', 'in', 'water', 'treated', 'a', 'couple', 'of', 'days', 'before', 'with', 'a', 'water', 'treatment', 'and', 'left', 'open', 'to', '"', 'breathe', '"', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'for', 'those', 'of', 'you', 'in', 'toronto', ',', 'i', 'apologize', 'for', 'not', 'being', 'able', 'to', 'schedule', 'this', 'over', 'your', 'lunch', 'time', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'have', 'a', '!DIGITS', 'months', 'shih', 'tzu', 'puppy', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'so', 'what', 'is', 'all', 'the', 'fuss', 'about', 'suicide', 'killings', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'true', 'or', 'false', ':', 'being', 'a', 'young', 'new', 'zealander', 'means', 'having', 'no', 'future', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '!DIGITS', 'am', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'july', '!DIGITS', ',', '!DIGITS', 'it', 'is', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'do', "n't", 'let', 'just', 'anybody', 'do', 'it', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', "'ve", 'never', 'done', 'that', 'before', 'though', 'either', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'and', 'they', "'re", 'working', 'towards', 'being', 'able', 'to', 'extradite', 'people', 'who', 'have', 'left', 'the', 'country', 'to', 'avoid', 'paying', 'it', 'back', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', 'brought', 'fabric', 'books', ',', 'and', 'pictures', 'of', 'furniture', 'only', ',', 'which', 'all', 'came', 'way', 'over', 'budget', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'set', 'up', 'last', 'month', 'to', 'centralize', 'merchant', 'asset', 'activities', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'amy', 'cornell', 'compaq', 'cpcg', 'marketing', 'p', ':', '!HYPHEN', 'f', ':', '!HYPHEN', 'amy.cornell@compaq.com', '<', 'mailto:amy.cornell@compaq.com', '<', 'mailto:amy.cornell@compaq.com', '>', '>', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'http://en.wikipedia.org/wiki/john_balance', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'freedom', 'from', 'the', 'fear', 'of', 'corporate', 'downsizing', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'affirm', 'freedom', 'of', 'conscience', 'in', 'this', 'matter', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'meanwhile', ',', 'a', 'decision', "'s", 'been', 'reached', 'in', 'the', 'trial', 'of', 'toledo', 'priest', 'gerald', 'robinson', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'would', 'like', 'to', 'informally', 'get', 'together', 'with', 'you', 'on', 'wednesday', ',', 'july', '!DIGITS', 'at', '!DIGITS', 'am', '-', '!DIGITS', 'pm', '(', 'max', ')', 'to', 'talk', 'about', 'your', 'recruiting', 'experience', 'with', 'enron', 'canada', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mr.', 'murph', 'archibald', '(', 'nephew', 'of', 'red', 'blount', ')', ':', 'well', ',', 'i', 'was', 'coming', 'in', 'early', 'in', 'the', 'morning', 'and', 'leaving', 'in', '!HYPHEN', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'any', 'suggestions', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thanks', 'again', 'to', 'my', 'friend', 'nick', 'keck', 'for', 'passing', 'this', 'along', 'via', '!HYPHEN', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'aquiriums', 'are', 'good', 'also', ',', 'but', 'provide', 'a', 'mesh', 'top', 'for', 'an', 'easy', 'airway', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'see', 'you', 're', 'still', 'recovering', 'from', 'the', 'accident', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'do', "n't", 'get', 'me', 'wrong', 'i', 'want', 'to', 'go', ',', 'but', 'for', '!DIGITS', 'days', '-_-', 'i', 'mean', 'seriously', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'a', 'pattern', 'of', 'arrests', 'and', 'seizures', 'indicate', 'that', 'arms', 'are', 'brought', 'by', 'the', 'ltte', 'from', 'laos', ',', 'cambodia', 'and', 'thailand', 'into', 'chittagong', ',', 'from', 'where', 'they', 'are', 'transported', 'northward', 'by', 'land', 'to', 'bhutan', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'expect', 'a', 'call', 'from', 'paul', 'tonight', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'lou', ',', 'do', 'we', 'have', 'any', 'sort', 'of', 'policy', 'on', 'requests', 'like', 'this', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'you', 'may', 'regard', 'my', 'views', 'as', 'those', 'of', 'the', 'proverbial', 'taxi', 'driver', ',', 'which', 'you', 'are', 'supposed', 'to', 'question', ',', 'when', 'you', 'visit', 'a', 'country', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'sagittarius', 'in', '!YEAR', '-', 'empowerment', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '___________', 'monday', ',', 'september', '!DIGITS', '!DIGITS', '-', '!DIGITS', 'pm', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'patty', 'lee', 'corporate', 'tax', 'x35172', 'eb', '!YEAR', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'call', 'me', 'to', 'discuss', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', 'stressed', ',', 'however', ',', 'that', 'nasa', 'would', 'not', 'follow', 'this', 'week', "'s", 'chinese', 'mission', 'through', 'formal', 'channels', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'still', 'would', 'not', 'drive', 'the', 'car', 'with', 'me', 'to', 'show', 'their', 'mpg', 'number', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'no', 'wine', 'glasses', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'so', 'very', 'delicious', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thanks', 'jim', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'use', 'them', 'to', 'look', 'prickly', '..', 'would', 'you', 'try', 'to', 'eat', 'a', 'cactus', '[', 'if', 'u', 'had', 'no', 'knife', ']', 'i', 'know', 'i', 'would', 'nt', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'sudan', 'is', 'the', 'primary', 'example', ',', '"', 'he', 'said', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'will', 'take', 'care', 'of', 'it', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', "'m", 'not', 'sure', 'that', 'there', "'s", 'much', 'nightlife', 'in', 'naha', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'creation', 'of', 'an', 'incentive', 'payment', 'pool', '(', 'possibly', 'via', 'personal', 'best', 'awards', ')', 'for', 'key', 'metals', 'staff', 'who', 'continue', 'to', 'work', 'exceptionally', 'unsociable', 'hours', 'to', 'meet', 'the', 'above', 'stated', 'objectives', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'term', 'of', 'the', 'transaction', 'shall', 'correspond', 'to', 'the', 'date', '(', 's', ')', 'set', 'forth', 'in', 'the', 'product', 'description', 'on', 'the', 'website', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'do', "n't", 'know', 'if', 'vomiting', 'blood', 'is', 'common', 'with', 'this', 'ailment', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '[', ']', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'there', 'was', 'a', 'change', 'made', 'in', 'the', 'coding', 'for', 'the', 'delta', 'position', 'and', 'this', 'has', 'somehow', 'messed', 'up', 'the', 'liq', 'value', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'bear', 'dwarfed', 'the', '!DIGITS', '-', 'foot', '-', '!DIGITS', 'mr.', 'parenteau', ',', 'knocking', 'him', 'to', 'the', 'ground', ',', 'he', 'said', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'where', 'are', 'you', 'living', 'these', 'days', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'or', 'do', 'i', 'need', 'to', 'reapply', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'also', 'start', 'the', 'day', 'with', 'no', 'nicks', 'or', 'dings', 'in', 'their', 'fins', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'denise', 'lagesse', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'in', 'a', 'few', 'days', 'the', 'snake', 'will', 'begin', 'to', 'shed', 'its', 'skin', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'ate', 'here', 'a', 'couple', 'times', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'also', 'appreciate', 'their', 'honesty', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'have', 'tried', 'feeding', 'him', '!DIGITS', 'or', '!DIGITS', 'live', 'pinkies', 'and', '!DIGITS', 'or', '!DIGITS', 'frozen', '(', 'thawed', ')', 'pinkies', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'are', 'you', 'kidding', 'me', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'please', 'continue', 'its', 'success', 'by', 'carefully', 'adhering', 'to', 'the', 'instructions', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'is', 'a', 'daily', 'routine', 'to', 'hear', 'the', 'same', 'leader', 'making', 'opposite', 'statements', 'in', 'arabic', 'to', 'his', 'people', 'and', 'in', 'english', 'to', 'the', 'rest', 'of', 'the', 'world', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'will', 'take', 'you', 'next', 'one', 'in', 'august', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'were', 'introduced', 'to', 'bistro', 'tallulah', 'by', 'traveler', '-', 'professional', 'diner', 'who', 'happens', 'to', 'own', 'the', 'adelphi', 'hotel', 'and', 'travels', 'the', 'world', '--', 'and', 'residing', 'in', 'paris', ',', 'london', ',', 'new', 'york', 'the', 'rest', 'of', 'the', 'year', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'at', 'a', 'time', 'of', 'heightened', 'tensions', 'between', 'tehran', 'and', 'washington', 'over', 'iran', "'s", 'nuclear', 'weapons', 'program', 'and', 'calls', 'by', '!HYPHEN', 'in', 'washington', 'that', 'a', 'second', 'bush', 'term', 'should', 'deal', 'with', 'iran', 'aggressively', ',', 'the', 'iranians', 'fear', 'that', 'shindand', 'could', 'be', 'used', 'as', 'a', 'listening', 'post', ',', 'spying', 'facility', 'and', 'even', 'a', 'launching', 'pad', 'for', 'any', 'future', 'us', 'actions', 'against', 'iran', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', 'was', 'originally', 'named', "'", 'googol', "'", ',', 'a', 'word', 'for', 'the', 'number', 'represented', 'by', '!DIGITS', 'followed', 'by', '!DIGITS', 'zeros', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'let', "'s", 'get', 'this', 'over', 'with', 'now', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'spoke', 'with', 'gerald', 'and', 'he', 'said', 'there', 'are', 'a', 'bunch', 'of', 'folks', 'hanging', 'around', 'dad', "'s", 'place', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'ten', 'years', 'later', 'your', 'check', 'should', 'still', 'be', 'the', 'same', 'or', 'greater', ',', 'fulfilling', 'the', 'promise', 'of', 'long', '-', 'term', 'residual', 'income', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'should', 'there', 'be', 'a', '(', 'groan', ')', 'meeting', 'on', 'this', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'not', 'really', '...', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mb', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'yeah', ',', 'this', 'complex', 'is', 'not', 'very', 'good', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '<<', 'file', ':', 'questar', 'so', 'trails', 'hub', 'interconnect', '!HYPHEN', '>>', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'you', "'ll", 'need', 'to', 'have', 'intermediate', 'french', 'to', 'have', 'a', 'good', 'time', 'in', 'paris', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'is', ',', 'after', 'all', ',', 'his', 'business', ',', 'and', 'if', 'he', 'wants', 'you', 'to', 'remain', 'a', 'customer', 'why', 'on', 'earth', 'is', 'he', 'doing', 'shoddy', 'work', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'what', ':', 'happy', 'hour', 'for', 'john', 'suarez', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'as', 'with', 'christian', 'identity', 'and', 'other', 'hate', '-', 'related', 'philosophies', 'tied', 'to', 'the', 'aryan', 'nations', 'and', 'the', '!HYPHEN', 'creativity', 'movement', ',', 'jeffs', 'has', 'preached', 'racism', 'as', 'well', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'would', 'like', 'to', 'thank', 'you', 'for', 'personally', 'taking', 'the', 'time', 'to', 'closely', 'review', 'my', 'application', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'that', 'rejection', 'got', 'to', 'the', 'point', 'that', 'george', 'harrison', 'kicked', 'yoko', 'ono', 'in', 'the', 'apple', 'studios', 'during', 'the', 'filming', 'of', 'let', 'it', 'be', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'like', 'william', 'shakspere', 'raphael', '(', 'the', 'painter', ')', 'died', 'on', 'his', 'april', 'birthday', 'laura', '&', 'bridget', "'s", 'day', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'silkie', 'crosses', 'are', 'great', 'birds', ',', 'and', 'very', 'neat', 'looking', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thank', 'you', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'will', 'continue', 'going', 'to', 'dave', 'at', 'midas', 'because', 'he', 'is', 'one', 'of', 'the', 'most', 'honest', 'business', 'owners', 'in', 'this', 'town', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'switzerland', 'is', 'one', ',', 'and', 'the', 'netherlands', 'are', 'passing', 'the', 'same', 'law', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'equipment', 'and', 'classes', 'are', "n't", 'good', 'enough', 'to', 'deal', 'with', 'the', 'rudeness', 'from', 'the', 'staff', '!!!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'in', 'the', 'last', 'several', 'months', ',', 'china', 'has', 'inked', 'deals', 'with', 'iran', 'for', '$', '!DIGITS', 'billion', 'dollars', 'worth', 'of', 'iranian', 'oil', 'and', 'natural', 'gas', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'on', 'the', 'rer', '/', 'metro', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'next', 'day', ',', 'no', 'one', 'could', 'find', 'my', 'wheel', 'lock', 'and', 'that', 'particular', 'technician', 'was', 'not', 'in', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'secondly', ',', 'the', 'enchladas', 'did', 'not', 'come', 'with', 'enchilada', 'sauce', '..', 'but', 'chili', '...', 'like', 'hormel', "'s", 'chili', '..', 'the', 'cheese', 'was', 'american', 'cheese', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'before', 'coming', 'to', 'acupuncture', 'doctor', 'i', 'was', 'a', 'big', 'baby', 'about', 'needles', 'and', 'only', 'came', 'because', 'my', 'boyfriend', "'s", 'aunt', 'recommended', 'it', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', 'percentage', 'of', 'americans', 'who', 'believe', 'that', '"', 'politics', 'and', 'government', 'are', 'too', 'complicated', 'to', 'understand', '.', '"', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'good', 'luck', ',', 'enjoy', 'your', 'time', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', "'m", 'willing', 'to', 'give', 'it', 'a', 'shot', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'there', 'was', 'certainly', 'more', 'despair', 'in', 'saddam', "'s", 'iraq', 'than', 'in', 'paul', 'bremmer', "'s", 'iraq', ',', 'and', 'no', 'one', 'exploded', 'himself', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'horrible', '!!!!', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'should', 'all', 'uk', 'towns', 'and', 'their', 'cafes', 'or', 'restaurants', 'provide', 'halal', 'food', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'excellent', 'service', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'will', 'also', 'be', 'having', 'my', 'other', 'vet', 'up', 'who', "'s", 'a', 'chiro', '&', 'acupuncturist', 'to', 'evaluate', 'him', 'for', 'wobblers', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'oh', ',', 'if', 'you', 'are', 'confused', '.', '-END-', '-END2-']
# =====
# ...
# =====
# ['-START-', '-START2-', 'where', 'and', 'to', 'whom', 'do', 'you', 'want', 'it', 'faxed', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'any', 'insult', 'to', 'the', 'collective', 'good', 'brings', 'us', 'all', 'down', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'earl', ',', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'outer', 'circle', 'can', 'not', 'be', 'eliminated', 'by', 'force', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'marly', 'asked', 'me', 'to', 'respond', 'to', 'you', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'who', 'are', 'we', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'if', 'not', ',', 'is', 'there', 'someone', 'else', 'that', 'will', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'schedule', 'your', 'first', 'appointment', 'online', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', "'s", 'probably', 'still', 'scared', 'and', 'unsure', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'can', 'handle', 'the', 'tractor', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'western', 'sheep', 'and', 'cattle', 'ranchers', ',', 'on', 'whose', 'behalf', 'this', 'extermination', 'campaign', 'was', 'conducted', ',', 'gratefully', 'dusted', 'their', 'hands', 'of', 'the', 'wolf', 'and', 'wrote', 'him', 'off', 'as', 'a', 'job', 'well', 'done', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'if', 'not', 'removed', 'immediately', ',', 'the', '(', 'iso', ')', 'price', 'cap', 'will', 'sow', 'confusion', 'in', 'the', 'market', ',', 'threaten', 'reliability', 'and', 'stifle', 'new', 'investment', 'in', 'generating', 'capacity', ',', "''", 'read', 'one', 'letter', 'written', 'by', 'duke', 'energy', 'vice', 'president', 'william', 'hall', 'iii', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'maybe', 'we', '(', 'enron', ')', 'could', 'review', 'it', 'tomorrow', 'morning', ',', 'then', 'send', 'it', 'to', 'fce', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'kay', 'mann', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '!DIGITS', 'am', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'bet', 'you', 'also', 'did', 'take', 'charcoal', 'as', 'it', 'is', 'used', 'for', 'barbecue', 'which', 'does', 'not', 'get', 'as', 'hot', 'as', 'real', 'coal', '(', 'e.g.', 'for', 'blacksmithing', 'one', 'needs', 'coal', ',', 'not', 'barbecue', 'charcoal', ')', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'sometimes', 'do', 'nt', 'get', 'along', '(', 'you', 'know', 'how', 'some', 'girls', 'are', 'lol', 'hahahaahh', 'but', 'for', 'real', 'though', ',', 'two', 'girls', 'tend', 'to', 'fight', 'a', 'lot', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'am', 'going', 'to', 'try', 'and', 'study', 'aboard', 'but', 'idk', 'where', 'i', 'can', 'go', 'i', 'can', 'not', 'decide', 'where', 'do', 'you', 'think', 'would', 'be', 'the', 'best', 'place', 'to', 'go', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'has', 'anyone', 'read', 'the', 'letter', 'purportedly', 'from', 'ahmadinejad', 'to', 'george', 'bush', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', 'percentage', 'of', 'americans', 'who', 'ca', "n't", 'name', 'the', 'chief', 'justice', 'of', 'the', 'united', 'states', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'am', 'vacation', 'until', 'the', '!DIGITS', 'but', 'per', 'is', 'up', 'to', 'speed', 'and', 'i', 'would', 'like', 'to', 'make', 'sure', 'that', 'you', 'keep', 'up', 'with', 'him', 'and', 'any', 'hr', '/', 'legal', 'activity', 'that', 'may', 'occur', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'for', 'a', 'long', 'time', ',', 'one', 'big', 'source', 'of', 'entertainment', 'missing', 'from', 'the', 'richmond', 'city', 'limits', 'was', 'a', 'first', '-', 'run', 'multiplex', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'at', 'some', 'point', 'he', 'will', 'feel', 'ok', 'with', 'this', 'and', 'you', 'can', 'then', 'close', 'the', 'door', 'but', 'not', 'for', 'long', 'at', 'all', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'unless', 'the', 'tank', 'has', 'a', 'built', 'in', 'overflow', 'box', '(', 'which', 'i', "'m", 'certain', 'it', 'does', "n't", ')', 'then', 'you', 'have', 'to', 'get', 'one', 'of', 'those', 'hang', 'on', 'back', 'overflow', 'boxes', 'so', 'that', 'you', 'can', 'install', 'a', 'sump', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'are', 'you', 'back', 'in', 'the', 'office', 'yet', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'how', 'does', 'late', 'january', 'sound', 'to', 'you', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'he', 'has', 'a', 'long', 'and', 'distinguished', 'record', ',', 'including', 'many', 'years', 'as', 'a', 'federal', 'appeals', 'judge', ',', 'the', 'next', 'level', 'below', 'supreme', 'court', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', "'s", 'so', 'much', 'fun', 'over', 'there', ',', 'and', 'i', "'m", 'positive', 'that', 'you', "'ll", 'love', 'it', '!', ':)', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'my', 'dad', 'just', 'does', "n't", 'understand', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '-', 'number', 'of', 'bush', 'administration', 'public', 'statements', 'on', 'national', 'security', 'and', 'defense', 'in', 'the', 'same', 'period', 'that', 'mentioned', 'iraq', 'or', 'saddam', 'hussein', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'need', 'to', 'include', 'all', 'outstanding', 'transactions', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mail', 'the', 'six', 'envelopes', 'to', 'the', 'following', 'addresses', ':', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', "'ve", 'booked', 'videoconference', 'room', '#', '!DIGITS', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'although', 'ramzi', 'binalshibh', 'provided', 'him', '$', '!DIGITS', 'in', 'july', ',', 'accused', 'september', '!DIGITS', 'conspirator', 'zacarias', 'moussaoui', 'told', 'his', 'trial', 'judge', 'that', 'he', 'had', 'an', 'al', 'qaeda', 'mission', 'that', 'would', 'have', 'come', 'after', 'the', 'terrorist', 'attacks', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'informed', 'tana', 'that', 'we', 'made', 'the', 'change', 'in', 'global', 'counterparty', 'to', 'include', ',', '"', 'a', 'division', 'of', 'cargill', 'incorporated', '"', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'pew', 'researchers', 'looked', 'at', 'about', '!DIGITS', 'studies', 'that', 'could', 'provide', 'an', 'assessment', 'of', 'whether', 'climate', 'was', 'affecting', 'biology', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'make', 'it', 'fifteen', 'the', 'next', 'day', ',', 'then', 'twenty', ',', 'and', 'so', 'on', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'would', 'highly', 'recommend', 'the', 'el', 'paradero', 'on', 'your', 'next', 'trip', 'to', 'santa', 'fe', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'this', 'friday', '-', 'michael', 'goes', 'for', 'a', 'visit', 'at', 'st.', 'francis', ',', 'which', 'may', 'be', 'his', 'new', 'school', '(', 'so', 'far', ',', 'so', 'good', ')', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'since', 'enron', "'s", 'employees', 'are', 'assigned', 'an', 'sap', 'identification', 'numbers', '(', 'p', 'number', ')', 'and', 'an', 'hr', 'number', ',', 'could', 'enron', 'as', 'a', 'company', 'use', 'these', 'ids', 'instead', 'of', 'the', 'ss', 'numbers', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'however', 'upon', 'our', 'arrival', 'no', 'one', 'there', '(', 'the', 'inn', 'was', 'open', ')', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'mark', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'what', 'would', 'you', 'get', 'if', 'you', 'cross', 'a', 'sussex', 'male', 'and', 'a', 'silkie', 'female', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'it', "'s", 'always', 'just', '"', 'okay', ',', "they're", 'feet', 'need', 'to', 'be', 'done', ',', 'better', 'call', 'the', 'farrier', '.', '"', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'we', 'elected', 'to', 'not', 'do', 'the', 'epm', 'test', 'because', 'there', 'was', 'no', 'neurological', 'signs', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'nice', 'local', 'pub', ',', 'excellent', 'food', '(', 'especially', 'wings', ')', ',', 'and', 'do', "n't", 'go', 'if', 'you', 'have', 'a', 'limited', 'amount', 'of', 'time', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'am', 'not', 'certain', 'about', 'the', 'needs', 'for', 'the', 'london', 'underwriting', '/', 'iv', 'group', 'but', 'will', 'request', 'the', 'information', 'from', 'them', 'if', 'you', 'have', 'not', 'done', 'so', 'already', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'tricky', 'short', 'guy', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'all', 'the', 'best', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'by', 'moving', 'quickly', 'to', 'iraqi', 'sovereignty', 'and', 'improvement', 'of', 'iraqi', 'lives', ',', 'the', 'us', 'may', 'be', 'able', 'to', 'get', 'iraqis', 'on', 'its', 'side', ',', 'so', 'that', 'they', 'turn', 'in', 'the', 'foreigners', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'assumed', 'a', 'value', '--', 'unspecified', '--', 'for', '!HYPHEN', 'species', ',', 'and', 'in', 'doing', 'so', 'rendered', 'the', 'warming', 'news', 'a', 'bit', 'less', 'rosy', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'talked', 'to', 'craig', 'and', 'the', 'court', 'today', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hit', 'the', 'road', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '"', 'as', 'an', 'example', ',', 'consider', 'the', 'treatment', 'of', 'the', 'civet', 'cat', ',', 'a', 'highly', 'intelligent', 'and', 'sociable', 'animal', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'thank', 'you', ':)', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'wool', 'is', 'best', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'that', 'was', '!DIGITS', 'years', 'ago', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'had', 'to', 'wait', 'for', 'my', 'waitress', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'money', 'funds', 'their', 'travel', ',', 'explosives', ',', 'hideouts', 'and', 'permanent', 'search', 'for', 'soft', 'vulnerable', 'targets', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'service', 'department', 'even', 'gave', 'me', 'a', 'ride', 'home', 'and', 'picked', 'me', 'up', 'when', 'my', 'car', 'was', 'finished', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'be', 'sure', 'not', 'to', 'feed', 'your', 'rabbits', '!HYPHEN', 'items', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', '!DIGITS', '!DIGITS', 'pm', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'if', 'your', '(', 'us', ')', 'provider', 'has', 'a', 'deal', 'with', 'a', 'canadian', 'wireless', 'company', ',', 'you', 'texts', 'and', 'calls', 'will', 'go', 'through', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'was', 'very', 'pleased', 'to', 'find', 'my', 'accommodations', 'and', 'the', 'hotel', 'staff', 'to', 'be', 'a', 'very', 'calming', 'and', 'comforting', 'part', 'of', 'my', 'trip', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'see', 'below', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'are', 'hoping', 'corp', 'will', 'foot', 'the', 'bill', 'for', 'a', 'pilot', 'which', 'will', 'allow', 'them', 'to', 'fully', 'test', 'this', 'tool', 'before', 'implementing', 'it', 'company', '-', 'wide', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'hazim', 'al', '-', "sha'lan", ',', 'by', 'the', 'way', ',', 'is', 'the', 'son', 'of', 'the', 'late', 'sheikh', 'of', 'al', '-', "khaza'il", 'in', 'diwaniya', 'and', 'has', 'the', 'potential', 'to', 'replace', 'former', 'information', 'minister', ',', 'm.s.', 'al', '-', 'sahaf', ',', 'in', 'his', 'nonsensical', 'media', 'statements', ',', 'which', 'can', 'be', 'passed', 'as', 'jokes', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'use', 'gimp', 'and', 'it', 's', 'not', 'cutting', 'it', ',', 'looks', 'terrible', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'in', 'a', 'limited', 'economic', 'sense', ',', 'therefore', ',', 'the', 'organization', 'can', 'argue', 'warming', 'might', 'be', 'a', 'good', 'thing', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'but', 'you', 'need', 'to', 'ask', 'yourself', 'do', 'you', 'feel', 'the', 'same', 'way', '?', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'john', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'think', 'that', 'we', 'will', 'stay', 'in', 'korea', 'when', 'your', 'parents', 'come', 'and', 'do', 'the', 'whole', 'base', 'thing', '(', 'which', 'will', 'take', 'only', 'a', 'few', 'minutes', ',', 'actually', ')', ',', 'but', 'are', 'considering', 'going', 'to', 'china', 'or', 'somewhere', 'during', 'part', 'of', 'thanksgiving', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'list', 'price', ':', '$', '!DIGITS', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'owner', 'warned', 'me', 'that', 'it', 'was', 'the', 'best', 'salsa', 'i', 'would', 'ever', 'had', ',', 'and', 'he', 'was', 'right', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'beatles', 'of', 'the', 'times', 'of', 'the', '"', 'cavern', '"', 'sounded', 'exactly', 'as', 'poorly', 'as', 'oasis', 'and', 'the', 'little', 'musical', 'quality', 'in', 'the', 'songs', 'of', 'the', 'beatles', 'is', 'due', 'to', 'george', 'martin', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'yes', ',', 'i', 'say', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'that', 'is', 'just', 'unheard', 'of', 'these', 'days', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'think', 'she', 'just', 'wants', 'to', 'be', 'able', 'to', 'touch', 'football', 'players', 'legs', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'the', 'transaction', 'is', 'for', 'hot', 'rolled', 'steel', 'with', 'a', 'thickness', 'of', '!DIGITS', '"', 'and', 'a', 'width', 'of', '!DIGITS', 'inches', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'kalkat', ',', 'who', 'currently', 'chairs', 'the', 'independent', 'us', '-', 'based', 'international', 'council', 'on', 'conflict', 'resolution', ',', 'said', 'despite', 'the', 'failure', 'of', 'the', 'indian', 'army', 'to', 'disarm', 'or', 'even', 'subdue', 'the', 'tigers', ',', 'india', 'remained', 'the', 'only', 'power', 'capable', 'of', 'influencing', 'the', 'course', 'of', 'the', 'current', 'peace', 'talks', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'i', 'have', 'a', 'few', 'entities', 'that', 'may', 'need', 'to', 'change', 'groups', 'or', 'be', 'assigned', 'to', 'a', 'group', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'so', ',', 'no', 'it', 'is', 'not', 'as', 'good', 'as', 'dubai', ',', 'but', 'it', 's', 'quieter', 'and', 'more', 'peaceful', ',', 'and', 'you', 'can', 'still', 'go', 'to', 'dubai', 'in', '!DIGITS', 'mins', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'a', 'few', 'squeaks', 'from', 'a', 'wheel', 'are', 'better', 'than', 'the', 'full', 'wrath', 'of', 'a', 'bored', 'pet', '!', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'esp.', 'the', 'mole', ',', 'tortilla', 'soup', ',', 'and', 'guacamole', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'they', 'are', 'social', 'and', 'like', 'to', 'be', 'handled', '.', '-END-', '-END2-']
# =====
# ['-START-', '-START2-', 'taking', 'into', 'consideration', 'this', 'class', 'of', 'customer', ',', 'we', 'decided', 'to', 'include', 'certain', 'items', ',', 'including', 'our', 'inability', 'to', 'cover', 'our', 'costs', 'due', 'to', 'a', 'change', 'in', 'law', ',', 'rules', 'or', 'practices', 'as', 'a', '"', 'force', 'majeure', 'event', '"', 'in', 'an', 'effort', 'to', 'soften', 'the', 'approach', '(', 'see', 'the', 'gtcs', ')', '.', '-END-', '-END2-']
# =====

# %%
import os
from spacy.en import English, LOCAL_DATA_DIR, DOC
data_dir = os.environ.get('SPACY_DATA', LOCAL_DATA_DIR)
nlp = English(parser=False, entity=False, data_dir=data_dir)

# %%
corpus = "\n".join(" ".join(y) for y in [x[0] for x in sentences_w_tags])

doc = nlp(unicode(corpus))

# %%
n = 0
print doc[n].lemma_
print doc[n].pos_
tags = []
for token in doc:
    if not token.pos_ in tags:
        tags.append(token.pos_)
        
Doc[n].data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-a2ecc9b7c5bd> in <module>()
# ----> 1 from spacy.en import English, LOCAL_DATA_DIR, Doc
#       2 n = 0
#       3 print doc[n].lemma_
#       4 print doc[n].pos_
#       5 tags = []
#
# ImportError: cannot import name Doc

# %%
#Get Test Corpus - " " seperated words "\n" seperated sentences
# and get list of correct tags
corpus=""
words=[]
test_correct_tags=[]
for line in open(testFile):

    vals = line.split('\t')
    if (len(vals) > 1):
        words.append(vals[1])
        test_correct_tags.append((vals[1],vals[3]))
    else:
        words.append("\n")
print(len(words))
#corpus=words
corpus = " ".join(words)
print corpus[0:20]
# Out:
# 27173
# What if Google Morph

# %%
#test_output_tags = pt.tag(corpus, False)
print(len(test_output_tags))
print(len(test_correct_tags))
test_output_tags[0:15]
# Out:
# 25096
# 25096
# [('What', 'PRON', 13.831999999999995),
#  ('if', 'SCONJ', 30),
#  ('Google', 'PROPN', 6.974),
#  ('Morphed', 'VERB', 7.185999999999996),
#  ('Into', 'ADP', 2.701000000000004),
#  ('GoogleOS', 'PROPN', 5.736000000000001),
#  ('?', 'PUNCT', 30),
#  ('What', 'PRON', 13.061999999999996),
#  ('if', 'SCONJ', 30),
#  ('Google', 'PROPN', 7.538999999999998),
#  ('expanded', 'VERB', 23.53),
#  ('on', 'ADP', 29.317999999999998),
#  ('its', 'PRON', 30),
#  ('search', 'NOUN', 13.594),
#  ('-', 'PUNCT', 21.266000000000002)]

# %%
import statistics as s
import copy

test_output_tags_c = copy.deepcopy(test_output_tags)
test_correct_tags_c = copy.deepcopy(test_correct_tags)

correct = 0
conf_right=[]
conf_total =0
conf_wrong=[]
poss_total = len(test_output_tags)
print poss_total
unconfident_total = 0
to_remove = []
for i in range(len(test_output_tags_c)):
    if (test_output_tags_c[i][2] <= 7):
        a=3#print (i, test_correct_tags_c[i], test_output_tags_c[i])
        to_remove.append(i)

#for index in reversed(to_remove):
#    del test_correct_tags_c[index]
#    del test_output_tags_c[index]
    
for i in range(len(test_output_tags_c)):
    if (test_correct_tags_c[i][1] == test_output_tags_c[i][1]):
        conf_right.append(test_output_tags_c[i][2])
        correct+=1
    else:
        conf_wrong.append(test_output_tags_c[i][2])
a = np.array(conf_right)
print "average confidence of right = " + str(s.mean(conf_right))
print "average confidence of wrong = " + str(s.mean(conf_wrong))
    
accc = 100.00* (1.0*correct)/poss_total

print  len(to_remove),poss_total
print "accuracy: " + str(accc) + "%"
print "accuracy adjusted " + str(100.0*correct/(poss_total-len(to_remove)))
# Out:
# 25096
# average confidence of right = 22.8366514118
# average confidence of wrong = 6.48423090909
# 2949 25096
# accuracy: 93.4252470513%
# accuracy adjusted 105.865354224

# %%
ac = [(1,93.449), (2,93.525),(5,93.53) (6,93.70), (8,93.72), (12,93.7599)]
a = [i[0] for i in ac]
b = [i[1] for i in ac]
a
b = 175.265

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(a,b)

# %%
acc_id="AC5387d3c4597807d2de889091148d126c"
auth_tok="1639f28d728c5cd85dfcbd57d231c39c"

from twilio.rest import TwilioRestClient
 
# Find these values at https://twilio.com/user/account
account_sid = "AC5387d3c4597807d2de889091148d126c"
auth_token = "1639f28d728c5cd85dfcbd57d231c39c"
client = TwilioRestClient(account_sid, auth_token)
 
message = client.messages.create(to="+15027949011", from_="+1 502-354-4142",
                                     body="done: accuracry = " + str(accc)+ "%")

# %%
import spacy.util
from spacy.en import English

from spacy.syntax.parser import OracleError
from spacy.syntax.util import Config

# %%
nlp = English()

# %%
tokens = nlp.tokenizer.tokens_from_list([u'Me', u'and', u'you, 'u'hate', u'pizza'])
a=nlp.tagger(tokens)
a=nlp.parser(tokens)

# %%
print tokens[1].head
# Out:
# Me
